# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car data.csv")
df.head(30)
#looking at the data
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# 11           ciaz  2015           6.85          10.38       51000    Diesel
# 12           ciaz  2015           7.50           9.94       15000    Petrol
# 13         ertiga  2015           6.10           7.71       26000    Petrol
# 14          dzire  2009           2.25           7.21       77427    Petrol
# 15         ertiga  2016           7.75          10.79       43000    Diesel
# 16         ertiga  2015           7.25          10.79       41678    Diesel
# 17         ertiga  2016           7.75          10.79       43000    Diesel
# 18        wagon r  2015           3.25           5.09       35500       CNG
# 19            sx4  2010           2.65           7.98       41442    Petrol
# 20       alto k10  2016           2.85           3.95       25000    Petrol
# 21          ignis  2017           4.90           5.71        2400    Petrol
# 22            sx4  2011           4.40           8.01       50000    Petrol
# 23       alto k10  2014           2.50           3.46       45280    Petrol
# 24        wagon r  2013           2.90           4.41       56879    Petrol
# 25          swift  2011           3.00           4.99       20000    Petrol
# 26          swift  2013           4.15           5.87       55138    Petrol
# 27          swift  2017           6.00           6.49       16200    Petrol
# 28       alto k10  2010           1.95           3.95       44542    Petrol
# 29           ciaz  2015           7.45          10.38       45000    Diesel
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# 5       Dealer       Manual      0
# 6       Dealer       Manual      0
# 7       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0
# 10      Dealer       Manual      0
# 11      Dealer       Manual      0
# 12      Dealer    Automatic      0
# 13      Dealer       Manual      0
# 14      Dealer       Manual      0
# 15      Dealer       Manual      0
# 16      Dealer       Manual      0
# 17      Dealer       Manual      0
# 18      Dealer       Manual      0
# 19      Dealer       Manual      0
# 20      Dealer       Manual      0
# 21      Dealer       Manual      0
# 22      Dealer    Automatic      0
# 23      Dealer       Manual      0
# 24      Dealer       Manual      0
# 25      Dealer       Manual      0
# 26      Dealer       Manual      0
# 27  Individual       Manual      0
# 28      Dealer       Manual      0
# 29      Dealer       Manual      0

# %%
car_depreciation = df['Present_Price'] - df['Selling_Price']
df['depreciation'] = car_depreciation
df
# Creating a new column depreciation to get the price drop(current price - selling price) and adding it to datafreame
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# 9             ciaz  2015           7.45           8.92       42367    Diesel
# 10        alto 800  2017           2.85           3.60        2135    Petrol
# 11            ciaz  2015           6.85          10.38       51000    Diesel
# 12            ciaz  2015           7.50           9.94       15000    Petrol
# 13          ertiga  2015           6.10           7.71       26000    Petrol
# 14           dzire  2009           2.25           7.21       77427    Petrol
# 15          ertiga  2016           7.75          10.79       43000    Diesel
# 16          ertiga  2015           7.25          10.79       41678    Diesel
# 17          ertiga  2016           7.75          10.79       43000    Diesel
# 18         wagon r  2015           3.25           5.09       35500       CNG
# 19             sx4  2010           2.65           7.98       41442    Petrol
# 20        alto k10  2016           2.85           3.95       25000    Petrol
# 21           ignis  2017           4.90           5.71        2400    Petrol
# 22             sx4  2011           4.40           8.01       50000    Petrol
# 23        alto k10  2014           2.50           3.46       45280    Petrol
# 24         wagon r  2013           2.90           4.41       56879    Petrol
# 25           swift  2011           3.00           4.99       20000    Petrol
# 26           swift  2013           4.15           5.87       55138    Petrol
# 27           swift  2017           6.00           6.49       16200    Petrol
# 28        alto k10  2010           1.95           3.95       44542    Petrol
# 29            ciaz  2015           7.45          10.38       45000    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 271           city  2009           3.00          10.00       69562    Petrol
# 272           city  2015           7.50          10.00       27600    Petrol
# 273           jazz  2010           2.25           7.50       61203    Petrol
# 274           brio  2014           5.30           6.80       16500    Petrol
# 275           city  2016          10.90          13.60       30753    Petrol
# 276           city  2015           8.65          13.60       24800    Petrol
# 277           city  2015           9.70          13.60       21780    Petrol
# 278           jazz  2016           6.00           8.40        4000    Petrol
# 279           city  2014           6.25          13.60       40126    Petrol
# 280           brio  2015           5.25           5.90       14465    Petrol
# 281           city  2006           2.10           7.60       50456    Petrol
# 282           city  2014           8.25          14.00       63000    Diesel
# 283           city  2016           8.99          11.80        9010    Petrol
# 284           brio  2013           3.50           5.90        9800    Petrol
# 285           jazz  2016           7.40           8.50       15059    Petrol
# 286           jazz  2016           5.65           7.90       28569    Petrol
# 287          amaze  2015           5.75           7.50       44000    Petrol
# 288           city  2015           8.40          13.60       34000    Petrol
# 289           city  2016          10.11          13.60       10980    Petrol
# 290          amaze  2014           4.50           6.40       19000    Petrol
# 291           brio  2015           5.40           6.10       31427    Petrol
# 292           jazz  2016           6.40           8.40       12000    Petrol
# 293           city  2010           3.25           9.90       38000    Petrol
# 294          amaze  2014           3.75           6.80       33019    Petrol
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  depreciation
# 0        Dealer       Manual      0          2.24
# 1        Dealer       Manual      0          4.79
# 2        Dealer       Manual      0          2.60
# 3        Dealer       Manual      0          1.30
# 4        Dealer       Manual      0          2.27
# 5        Dealer       Manual      0          0.58
# 6        Dealer       Manual      0          1.37
# 7        Dealer       Manual      0          2.11
# 8        Dealer       Manual      0          0.14
# 9        Dealer       Manual      0          1.47
# 10       Dealer       Manual      0          0.75
# 11       Dealer       Manual      0          3.53
# 12       Dealer    Automatic      0          2.44
# 13       Dealer       Manual      0          1.61
# 14       Dealer       Manual      0          4.96
# 15       Dealer       Manual      0          3.04
# 16       Dealer       Manual      0          3.54
# 17       Dealer       Manual      0          3.04
# 18       Dealer       Manual      0          1.84
# 19       Dealer       Manual      0          5.33
# 20       Dealer       Manual      0          1.10
# 21       Dealer       Manual      0          0.81
# 22       Dealer    Automatic      0          3.61
# 23       Dealer       Manual      0          0.96
# 24       Dealer       Manual      0          1.51
# 25       Dealer       Manual      0          1.99
# 26       Dealer       Manual      0          1.72
# 27   Individual       Manual      0          0.49
# 28       Dealer       Manual      0          2.00
# 29       Dealer       Manual      0          2.93
# ..          ...          ...    ...           ...
# 271      Dealer       Manual      0          7.00
# 272      Dealer       Manual      0          2.50
# 273      Dealer       Manual      0          5.25
# 274      Dealer       Manual      0          1.50
# 275      Dealer    Automatic      0          2.70
# 276      Dealer       Manual      0          4.95
# 277      Dealer       Manual      0          3.90
# 278      Dealer       Manual      0          2.40
# 279      Dealer       Manual      0          7.35
# 280      Dealer       Manual      0          0.65
# 281      Dealer       Manual      0          5.50
# 282      Dealer       Manual      0          5.75
# 283      Dealer       Manual      0          2.81
# 284      Dealer       Manual      0          2.40
# 285      Dealer    Automatic      0          1.10
# 286      Dealer       Manual      0          2.25
# 287      Dealer    Automatic      0          1.75
# 288      Dealer       Manual      0          5.20
# 289      Dealer       Manual      0          3.49
# 290      Dealer       Manual      0          1.90
# 291      Dealer       Manual      0          0.70
# 292      Dealer       Manual      0          2.00
# 293      Dealer       Manual      0          6.65
# 294      Dealer       Manual      0          3.05
# 295      Dealer       Manual      0          4.54
# 296      Dealer       Manual      0          2.10
# 297      Dealer       Manual      0          1.90
# 298      Dealer       Manual      0          7.65
# 299      Dealer       Manual      0          1.00
# 300      Dealer       Manual      0          0.60
#
# [301 rows x 10 columns]

# %%
depr = df[['Car_Name', 'depreciation']]
#creating a new dataframe and saving as depr
depr.head()
# Out:
#   Car_Name  depreciation
# 0     ritz          2.24
# 1      sx4          4.79
# 2     ciaz          2.60
# 3  wagon r          1.30
# 4    swift          2.27

# %%
grouped = depr.groupby('Car_Name').mean()
#getting the depreciating value by the help of car name by clubbing them into one
grouped.sort_values('depreciation', ascending=False)
#ascending is set as false
# Out:
#                           depreciation
# Car_Name
# land cruiser                 57.600000
# camry                        21.230000
# fortuner                     12.047273
# corolla                      10.850000
# corolla altis                10.399375
# innova                        5.068889
# sx4                           4.908333
# city                          4.372692
# etios cross                   3.333333
# verna                         3.292143
# elantra                       3.190000
# dzire                         3.157500
# etios gd                      3.100000
# ertiga                        2.848333
# etios liva                    2.667500
# amaze                         2.564286
# etios g                       2.520000
# ritz                          2.475000
# i20                           2.438889
# jazz                          2.328571
# ciaz                          2.284444
# xcent                         2.163333
# s cross                       2.110000
# Hyosung GT250R                2.100000
# baleno                        2.020000
# wagon r                       1.937500
# 800                           1.930000
# swift                         1.802000
# creta                         1.800000
# eon                           1.530000
# ...                                ...
# TVS Wego                      0.270000
# TVS Apache RTR 160            0.253333
# Mahindra Mojo XT300           0.250000
# Bajaj Pulsar 135 LS           0.240000
# Yamaha FZ  v 2.0              0.240000
# Yamaha FZ S V 2.0             0.236667
# Activa 3g                     0.220000
# Honda Activa 125              0.220000
# Hero Honda Passion Pro        0.210000
# Bajaj Pulsar RS200            0.210000
# Bajaj Avenger 150 street      0.200000
# Bajaj Discover 100            0.200000
# Hero Extreme                  0.187000
# Hero Splender Plus            0.180000
# TVS Jupyter                   0.170000
# Bajaj Avenger 220             0.160000
# Honda CB Hornet 160R          0.153333
# Bajaj Dominar 400             0.150000
# Bajaj  ct 100                 0.140000
# Hero Passion Pro              0.125000
# UM Renegade Mojave            0.120000
# Royal Enfield Bullet 350      0.120000
# Hero Splender iSmart          0.115000
# Activa 4g                     0.110000
# Yamaha FZ 16                  0.070000
# Honda Dream Yuga              0.060000
# Hero Passion X pro            0.050000
# Bajaj Avenger 150             0.050000
# Honda Activa 4G               0.045000
# TVS Sport                     0.040000
#
# [98 rows x 1 columns]

# %% [markdown]
# ****Checking the relation of depriciation with multiple factor

# %%
df['Car_Name'].value_counts()
#counting the values of the names in the Car name
# Out:
# city                         26
# corolla altis                16
# verna                        14
# fortuner                     11
# brio                         10
# i20                           9
# ciaz                          9
# innova                        9
# grand i10                     8
# jazz                          7
# amaze                         7
# Royal Enfield Classic 350     7
# eon                           6
# ertiga                        6
# sx4                           6
# alto k10                      5
# swift                         5
# i10                           5
# etios liva                    4
# wagon r                       4
# ritz                          4
# Royal Enfield Thunder 350     4
# Bajaj Pulsar 150              4
# dzire                         4
# Bajaj Pulsar NS 200           3
# etios g                       3
# TVS Apache RTR 160            3
# creta                         3
# Royal Enfield Thunder 500     3
# xcent                         3
#                              ..
# Honda CB Trigger              1
# camry                         1
# s cross                       1
# Hero Honda Passion Pro        1
# 800                           1
# Honda Dream Yuga              1
# Activa 4g                     1
# alto 800                      1
# Hyosung GT250R                1
# Mahindra Mojo XT300           1
# TVS Wego                      1
# Bajaj Pulsar 135 LS           1
# Honda Activa 125              1
# vitara brezza                 1
# Bajaj Avenger Street 220      1
# Bajaj Pulsar RS200            1
# Hero Passion X pro            1
# Hero  Ignitor Disc            1
# Hero Super Splendor           1
# Hero Honda CBZ extreme        1
# Yamaha FZ 16                  1
# Honda CB Unicorn              1
# Bajaj Avenger 150             1
# TVS Sport                     1
# Bajaj Dominar 400             1
# KTM RC390                     1
# Yamaha Fazer                  1
# omni                          1
# TVS Jupyter                   1
# Hero  CBZ Xtreme              1
# Name: Car_Name, Length: 98, dtype: int64

# %%
city = df.loc[df['Car_Name'] == 'city']
city
#checking the city model
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 251     city  2013           5.00           9.90       56701    Petrol
# 253     city  2014           7.20           9.90       48000    Diesel
# 254     city  2013           5.25           9.90       54242    Petrol
# 256     city  2016          10.25          13.60       49562    Petrol
# 257     city  2015           8.50          13.60       40324    Petrol
# 258     city  2015           8.40          13.60       25000    Petrol
# 260     city  2016           9.15          13.60       29223    Petrol
# 267     city  2016           8.35           9.40       19434    Diesel
# 269     city  2015           6.70          10.00       18828    Petrol
# 270     city  2011           4.10          10.00       69341    Petrol
# 271     city  2009           3.00          10.00       69562    Petrol
# 272     city  2015           7.50          10.00       27600    Petrol
# 275     city  2016          10.90          13.60       30753    Petrol
# 276     city  2015           8.65          13.60       24800    Petrol
# 277     city  2015           9.70          13.60       21780    Petrol
# 279     city  2014           6.25          13.60       40126    Petrol
# 281     city  2006           2.10           7.60       50456    Petrol
# 282     city  2014           8.25          14.00       63000    Diesel
# 283     city  2016           8.99          11.80        9010    Petrol
# 288     city  2015           8.40          13.60       34000    Petrol
# 289     city  2016          10.11          13.60       10980    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
#
#     Seller_Type Transmission  Owner  depreciation
# 251      Dealer       Manual      0          4.90
# 253      Dealer       Manual      0          2.70
# 254      Dealer       Manual      0          4.65
# 256      Dealer       Manual      0          3.35
# 257      Dealer       Manual      0          5.10
# 258      Dealer       Manual      0          5.20
# 260      Dealer       Manual      0          4.45
# 267      Dealer       Manual      0          1.05
# 269      Dealer       Manual      0          3.30
# 270      Dealer       Manual      0          5.90
# 271      Dealer       Manual      0          7.00
# 272      Dealer       Manual      0          2.50
# 275      Dealer    Automatic      0          2.70
# 276      Dealer       Manual      0          4.95
# 277      Dealer       Manual      0          3.90
# 279      Dealer       Manual      0          7.35
# 281      Dealer       Manual      0          5.50
# 282      Dealer       Manual      0          5.75
# 283      Dealer       Manual      0          2.81
# 288      Dealer       Manual      0          5.20
# 289      Dealer       Manual      0          3.49
# 293      Dealer       Manual      0          6.65
# 295      Dealer       Manual      0          4.54
# 296      Dealer       Manual      0          2.10
# 298      Dealer       Manual      0          7.65
# 299      Dealer       Manual      0          1.00

# %%
plt.bar(x = city['Year'], height=city['depreciation'])
plt.xlabel('Year')
plt.ylabel('Depreciation in lacs')
plt.show()
# printing graph bar graph for city model

# %%
fortuner = df.loc[df['Car_Name'] == 'fortuner']
fortuner
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50  fortuner  2012          14.90          30.61      104707    Diesel
# 51  fortuner  2015          23.00          30.61       40000    Diesel
# 53  fortuner  2013          16.00          30.61      135000    Diesel
# 59  fortuner  2014          19.99          35.96       41000    Diesel
# 62  fortuner  2014          18.75          35.96       78000    Diesel
# 63  fortuner  2015          23.50          35.96       47000    Diesel
# 64  fortuner  2017          33.00          36.23        6000    Diesel
# 67  fortuner  2010           9.25          20.45       59000    Diesel
# 79  fortuner  2012          14.50          30.61       89000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
# 99  fortuner  2010           9.65          20.45       50024    Diesel
#
#    Seller_Type Transmission  Owner  depreciation
# 50      Dealer    Automatic      0         15.71
# 51      Dealer    Automatic      0          7.61
# 53  Individual    Automatic      0         14.61
# 59      Dealer    Automatic      0         15.97
# 62      Dealer    Automatic      0         17.21
# 63      Dealer    Automatic      0         12.46
# 64      Dealer    Automatic      0          3.23
# 67      Dealer       Manual      0         11.20
# 79      Dealer    Automatic      0         16.11
# 93      Dealer    Automatic      0          7.61
# 99      Dealer       Manual      0         10.80

# %%
plt.bar(x = fortuner['Year'], height=fortuner['depreciation'])
plt.xlabel('Year')
plt.ylabel('Depreciation in lacs')
plt.show()

# %%
kms = df[['Car_Name', 'Kms_Driven']]
kms.head(10)
# Out:
#         Car_Name  Kms_Driven
# 0           ritz       27000
# 1            sx4       43000
# 2           ciaz        6900
# 3        wagon r        5200
# 4          swift       42450
# 5  vitara brezza        2071
# 6           ciaz       18796
# 7        s cross       33429
# 8           ciaz       20273
# 9           ciaz       42367

# %%
by_kms_driven = kms.groupby('Car_Name').mean().head(30)
#grouping the car name and then taking their mean
by_kms_driven.sort_values('Kms_Driven',ascending=None)
# Out:
#                              Kms_Driven
# Car_Name
# Activa 3g                 250250.000000
# 800                       127000.000000
# Hero Honda CBZ extreme     75000.000000
# Hero Honda Passion Pro     60000.000000
# Hero Super Splendor        55000.000000
# Hero Splender Plus         50000.000000
# Hero  CBZ Xtreme           50000.000000
# Hero Hunk                  49000.000000
# Bajaj Pulsar 150           45808.250000
# Bajaj  ct 100              35000.000000
# Bajaj Pulsar 220 F         34500.000000
# Hero Passion X pro         31000.000000
# Bajaj Discover 125         30000.000000
# Bajaj Pulsar  NS 200       25000.000000
# Bajaj Pulsar NS 200        24166.666667
# Hero  Ignitor Disc         24000.000000
# Bajaj Avenger Street 220   24000.000000
# Bajaj Avenger 220 dtsi     21800.000000
# Bajaj Discover 100         21000.000000
# Bajaj Avenger 150 street   20000.000000
# Hero Glamour               18000.000000
# Hero Extreme               15500.000000
# Hero Splender iSmart       14000.000000
# Bajaj Pulsar 135 LS        13700.000000
# Bajaj Avenger 150           7000.000000
# Bajaj Pulsar RS200          5700.000000
# Hero Passion Pro            3850.000000
# Bajaj Avenger 220           1766.666667
# Activa 4g                   1300.000000
# Bajaj Dominar 400           1200.000000

# %%
plt.bar(x = city['depreciation'], height=city['Kms_Driven'])
plt.xlabel('Depreciation in lacs')
plt.ylabel('Kms Driven')
plt.show()

# %%
plt.bar(x = fortuner['depreciation'], height=fortuner['Kms_Driven'])
plt.xlabel('Depreciation in lacs')
plt.ylabel('Kms Driven')
plt.show()

# %% [markdown]
# #Depriciation due to kms
#
# The above graph shows somewhat constant behaviour for depreciation agaist kms driven, howevere even kms driven cannot be considered as sole factor affecting depreciation for studying other variables we need to transform them to get a better understanding of their importance in depreciation of car.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(df['Fuel_Type'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['CNG', 'Diesel', 'Petrol'], dtype=object)

# %%
df['Fuel_Type'] = le.transform(df['Fuel_Type'])
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type Transmission  Owner  depreciation
# 0      Dealer       Manual      0          2.24
# 1      Dealer       Manual      0          4.79
# 2      Dealer       Manual      0          2.60
# 3      Dealer       Manual      0          1.30
# 4      Dealer       Manual      0          2.27

# %%
le.fit(df['Seller_Type'])
# Out:
# LabelEncoder()

# %%
df['Seller_Type'] = le.transform(df['Seller_Type'])

# %%
le.classes_
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type Transmission  Owner  depreciation
# 0            0       Manual      0          2.24
# 1            0       Manual      0          4.79
# 2            0       Manual      0          2.60
# 3            0       Manual      0          1.30
# 4            0       Manual      0          2.27

# %%
le.fit(df['Transmission'])
# Out:
# LabelEncoder()

# %%
df['Transmission'] = le.transform(df['Transmission'])

# %%
le.classes_
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner  depreciation
# 0            0             1      0          2.24
# 1            0             1      0          4.79
# 2            0             1      0          2.60
# 3            0             1      0          1.30
# 4            0             1      0          2.27

# %%
by_fuel_type = df[['Car_Name', 'Fuel_Type', 'depreciation','Kms_Driven']]
by_fuel_type.head()
# Out:
#   Car_Name  Fuel_Type  depreciation  Kms_Driven
# 0     ritz          2          2.24       27000
# 1      sx4          1          4.79       43000
# 2     ciaz          2          2.60        6900
# 3  wagon r          2          1.30        5200
# 4    swift          1          2.27       42450

# %%
fuel_t = by_fuel_type.groupby('Fuel_Type').mean()
fuel_t.head()
# Out:
#            depreciation    Kms_Driven
# Fuel_Type
# 0              3.315000  42749.000000
# 1              5.536000  50369.916667
# 2              2.319372  33528.937238

# %%
by_seller_t = df[['Car_Name', 'Seller_Type', 'depreciation']]
by_seller_t.head()
# Out:
#   Car_Name  Seller_Type  depreciation
# 0     ritz            0          2.24
# 1      sx4            0          4.79
# 2     ciaz            0          2.60
# 3  wagon r            0          1.30
# 4    swift            0          2.27

# %%
seller_t = by_seller_t.groupby('Seller_Type').mean()
# by_kms_driven.sort_values('Kms_Driven', ascending=False)
seller_t.head()
# Out:
#              depreciation
# Seller_Type
# 0                4.164615
# 1                0.764340

# %%
new_df = df[['Car_Name', 'Year', 'Kms_Driven', 'depreciation']]
new_df.head()
# Out:
#   Car_Name  Year  Kms_Driven  depreciation
# 0     ritz  2014       27000          2.24
# 1      sx4  2013       43000          4.79
# 2     ciaz  2017        6900          2.60
# 3  wagon r  2011        5200          1.30
# 4    swift  2014       42450          2.27

# %%
sns.pairplot(new_df)
plt.show()

# %%
final_val = df[['Car_Name', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'depreciation','Year', 'Transmission']]
final_val.head()
# Out:
#   Car_Name  Kms_Driven  Fuel_Type  Seller_Type  depreciation  Year  \
# 0     ritz       27000          2            0          2.24  2014
# 1      sx4       43000          1            0          4.79  2013
# 2     ciaz        6900          2            0          2.60  2017
# 3  wagon r        5200          2            0          1.30  2011
# 4    swift       42450          1            0          2.27  2014
#
#    Transmission
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
sns.pairplot(final_val)
plt.show()
